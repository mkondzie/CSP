# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import random
import os
import imageio.v2 as imageio

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def randomAtRadius(radius, seedX, seedY):
    theta = 2*np.pi*np.random.random()
    x=int(radius*np.cos(theta))+seedX
    y=int(radius*np.sin(theta))+seedY
    location=[x, y]
    return location

# %%
def checkAround(location, squareSize, matrix):
	foundFriend = False #found another particle
	exitCircle = False #reached the required radius
	nearEdge=False #near the edge of the field


    # Check if a walker is near the edge
	if (location[1] + 1) > squareSize - 1 or (location[1] - 1) < 1 or (location[0] + 1) > squareSize - 1 or (location[0] - 1) < 1:
		nearEdge = True

    # If not near the edge, check if the walker is near a neighbor or reached the required radius
    # location[1]=row, location[2]=column
	if not nearEdge:
		neighborDown = matrix[location[1]+1, location[0]]
		if neighborDown == 1:
			foundFriend = True
		if neighborDown == 2:
			exitCircle = True

		neighborUp=matrix[location[1] - 1 , location[0]]
		if neighborUp==1:
			foundFriend=True
		if neighborUp==2:
			exitCircle=True

		neighborRight=matrix[location[1], location[0] + 1]
		if neighborRight==1:
			foundFriend=True
		if neighborRight==2:
			exitCircle=True

		neighborLeft=matrix[location[1], location[0] - 1]
		if neighborLeft==1:
			foundFriend=True
		if neighborLeft==2:
			exitCircle=True

    # After checking locations, if locations are good, start the random walk
	if not foundFriend and not nearEdge:
		decide = np.random.random()
		if decide<0.25:
			location = [location[0] - 1,location[1]]
		elif decide<0.5:
			location = [location[0] + 1,location[1]]
		elif decide<0.75:
			location = [location[0],location[1] + 1]
		else:
			location = [location[0],location[1] - 1]

	return (location, foundFriend, nearEdge, exitCircle)

# %%
def save_image(matrix, addedCount):
    cmap = colors.ListedColormap(['teal','azure', 'teal'])
    label = str(addedCount)
    plt.matshow(matrix, fignum=None, interpolation='nearest', cmap=cmap)
    plt.savefig("/content/gdrive/MyDrive/5SEM/SIM/images/cluster{}.png".format(label), dpi=200)
    plt.close()

# %%
def initialize_matrix(radius):
    seedX = radius + 2
    seedY = radius + 2
    squareSize = radius * 2 + 5

    matrix = np.zeros((squareSize, squareSize), dtype=np.int32)

    for row in range(squareSize):
        for col in range(squareSize):
            # Put a seed particle
            if row == seedY and col == seedX:
                matrix[row, col] = 1
            # Define field outside of the circle
            elif (seedX - col) ** 2 + (seedY - row) ** 2 > radius ** 2:
                matrix[row, col] = 2

    return seedX, seedY, squareSize, matrix

# %%
def DLAcluster(radius, needGif):

    seedX, seedY, squareSize, matrix = initialize_matrix(radius)

    # Initialize the random walker counter
    randomWalkersCount = 0
    random.seed()
    # Set the cluster to NOT be complete
    completeCluster = False

    #keep track of number added
    addedCount=0

    # initialize array for the used interval for graphing
    usedInterval=[]

    while not completeCluster:
        # Release a walker
        randomWalkersCount += 1

        # Generate a (Xstart, Ystart) for walker, need within radius
        location=randomAtRadius(radius, seedX, seedY)

        # Initialize variables, like Friend tag and near edge identifier
        foundFriend = False #not near other particle
        nearEdge=False #not near the edge of the field


        # Set an individual walker out, stop if found a 'friend', give up if it reached the edge of the board
        while not foundFriend and not nearEdge:
            # Run the checking/walking function
            locationNew,foundFriend, nearEdge, exitCircle = checkAround(location,squareSize,matrix)

            # Add to the cluster if near a friend
            if foundFriend:
                # current location, replace with 1 and stop
                matrix[location[1]][location[0]] = 1
                addedCount+=1
            # Otherwise, save the location
            else:
                location = locationNew

        #print update
        intervalSavePic=range(0,400000,50)
        if addedCount in intervalSavePic:
            print("still working, have added ", randomWalkersCount, " random walkers.", " Added to cluster: ", addedCount)
        if needGif:
            if addedCount in intervalSavePic:
                print("save picture")
                usedInterval.append(addedCount) #append to the used count
                save_image(matrix, addedCount)
        if randomWalkersCount==400000:
            print("CAUTION: had to break the cycle, taking too many iterations")
            completeCluster = True

        # Once it finds a friend and leaves the previous loop, we must check if it
        # is also touching a circular wall. If so, we have a complete cluster
        if foundFriend and exitCircle:
            print("Random walkers in the cluster: ", addedCount)
            completeCluster = True

    save_image(matrix, '')


    if needGif:
      writer = imageio.get_writer('/content/gdrive/MyDrive/5SEM/SIM/images/movie.gif', mode='I')
      for i in usedInterval:
        try:
          filename = "/content/gdrive/MyDrive/5SEM/SIM/images/cluster" + str(i) + ".png"
          image = imageio.imread(filename)
          writer.append_data(image)
          os.remove(filename)
        except FileNotFoundError:
          continue
      image = imageio.imread("/content/gdrive/MyDrive/5SEM/SIM/images/cluster.png")
      writer.append_data(image)
      writer.close()



    return addedCount, matrix

# %%
# %%time
mass, matrix = DLAcluster(100, True)
plt.matshow(matrix, fignum=None, interpolation='nearest', cmap=colors.ListedColormap(['teal','azure', 'teal']))
plt.show()
# Out:
# still working, have added  1  random walkers.  Added to cluster:  0
# save picture
# still working, have added  2  random walkers.  Added to cluster:  0
# save picture
# still working, have added  3  random walkers.  Added to cluster:  0
# save picture
# still working, have added  4  random walkers.  Added to cluster:  0
# save picture
# still working, have added  5  random walkers.  Added to cluster:  0
# save picture
# still working, have added  6  random walkers.  Added to cluster:  0
# save picture
# still working, have added  7  random walkers.  Added to cluster:  0
# save picture
# still working, have added  8  random walkers.  Added to cluster:  0
# save picture
# still working, have added  9  random walkers.  Added to cluster:  0
# save picture
# still working, have added  10  random walkers.  Added to cluster:  0
# save picture
# still working, have added  11  random walkers.  Added to cluster:  0
# save picture
# still working, have added  12  random walkers.  Added to cluster:  0
# save picture
# still working, have added  13  random walkers.  Added to cluster:  0
# save picture
# still working, have added  14  random walkers.  Added to cluster:  0
# save picture
# still working, have added  15  random walkers.  Added to cluster:  0
# save picture
# still working, have added  16  random walkers.  Added to cluster:  0
# save picture
# still working, have added  17  random walkers.  Added to cluster:  0
# save picture
# still working, have added  18  random walkers.  Added to cluster:  0
# save picture
# still working, have added  19  random walkers.  Added to cluster:  0
# save picture
# still working, have added  20  random walkers.  Added to cluster:  0
# save picture
# still working, have added  21  random walkers.  Added to cluster:  0
# save picture
# still working, have added  22  random walkers.  Added to cluster:  0
# save picture
# still working, have added  23  random walkers.  Added to cluster:  0
# save picture
# still working, have added  24  random walkers.  Added to cluster:  0
# save picture
# still working, have added  25  random walkers.  Added to cluster:  0
# save picture
# still working, have added  26  random walkers.  Added to cluster:  0
# save picture
# still working, have added  27  random walkers.  Added to cluster:  0
# save picture
# still working, have added  28  random walkers.  Added to cluster:  0
# save picture
# still working, have added  29  random walkers.  Added to cluster:  0
# save picture
# still working, have added  30  random walkers.  Added to cluster:  0
# save picture
# still working, have added  31  random walkers.  Added to cluster:  0
# save picture
# still working, have added  32  random walkers.  Added to cluster:  0
# save picture
# still working, have added  33  random walkers.  Added to cluster:  0
# save picture
# still working, have added  34  random walkers.  Added to cluster:  0
# save picture
# still working, have added  35  random walkers.  Added to cluster:  0
# save picture
# still working, have added  36  random walkers.  Added to cluster:  0
# save picture
# still working, have added  37  random walkers.  Added to cluster:  0
# save picture
# still working, have added  38  random walkers.  Added to cluster:  0
# save picture
# still working, have added  39  random walkers.  Added to cluster:  0
# save picture
# still working, have added  40  random walkers.  Added to cluster:  0
# save picture
# still working, have added  41  random walkers.  Added to cluster:  0
# save picture
# still working, have added  42  random walkers.  Added to cluster:  0
# save picture
# still working, have added  43  random walkers.  Added to cluster:  0
# save picture
# still working, have added  44  random walkers.  Added to cluster:  0
# save picture
# still working, have added  45  random walkers.  Added to cluster:  0
# save picture
# still working, have added  46  random walkers.  Added to cluster:  0
# save picture
# still working, have added  47  random walkers.  Added to cluster:  0
# save picture
# still working, have added  48  random walkers.  Added to cluster:  0
# save picture
# still working, have added  49  random walkers.  Added to cluster:  0
# save picture
# still working, have added  50  random walkers.  Added to cluster:  0
# save picture
# still working, have added  51  random walkers.  Added to cluster:  0
# save picture
# still working, have added  52  random walkers.  Added to cluster:  0
# save picture
# still working, have added  1853  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1854  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1855  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1856  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1857  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1858  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1859  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1860  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1861  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1862  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1863  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1864  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1865  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1866  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1867  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1868  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1869  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1870  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1871  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1872  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1873  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1874  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1875  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1876  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1877  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1878  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1879  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1880  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1881  random walkers.  Added to cluster:  50
# save picture
# still working, have added  1882  random walkers.  Added to cluster:  50
# save picture
# still working, have added  3381  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3382  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3383  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3384  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3385  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3386  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3387  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3388  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3389  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3390  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3391  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3392  random walkers.  Added to cluster:  100
# save picture
# still working, have added  3393  random walkers.  Added to cluster:  100
# save picture
# still working, have added  4964  random walkers.  Added to cluster:  150
# save picture
# still working, have added  4965  random walkers.  Added to cluster:  150
# save picture
# still working, have added  4966  random walkers.  Added to cluster:  150
# save picture
# still working, have added  4967  random walkers.  Added to cluster:  150
# save picture
# still working, have added  5995  random walkers.  Added to cluster:  200
# save picture
# still working, have added  5996  random walkers.  Added to cluster:  200
# save picture
# still working, have added  5997  random walkers.  Added to cluster:  200
# save picture
# still working, have added  5998  random walkers.  Added to cluster:  200
# save picture
# still working, have added  5999  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6000  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6001  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6002  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6003  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6004  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6005  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6006  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6007  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6008  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6009  random walkers.  Added to cluster:  200
# save picture
# still working, have added  6880  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6881  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6882  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6883  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6884  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6885  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6886  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6887  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6888  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6889  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6890  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6891  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6892  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6893  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6894  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6895  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6896  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6897  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6898  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6899  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6900  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6901  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6902  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6903  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6904  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6905  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6906  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6907  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6908  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6909  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6910  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6911  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6912  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6913  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6914  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6915  random walkers.  Added to cluster:  250
# save picture
# still working, have added  6916  random walkers.  Added to cluster:  250
# save picture
# still working, have added  8052  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8053  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8054  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8055  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8056  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8057  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8058  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8059  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8060  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8061  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8062  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8063  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8064  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8065  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8066  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8067  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8068  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8069  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8070  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8071  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8072  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8073  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8074  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8075  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8076  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8077  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8078  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8079  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8080  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8081  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8082  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8083  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8084  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8085  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8086  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8087  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8088  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8089  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8090  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8091  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8092  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8093  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8094  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8095  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8096  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8097  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8098  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8099  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8100  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8101  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8102  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8103  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8104  random walkers.  Added to cluster:  300
# save picture
# still working, have added  8953  random walkers.  Added to cluster:  350
# save picture
# still working, have added  8954  random walkers.  Added to cluster:  350
# save picture
# still working, have added  8955  random walkers.  Added to cluster:  350
# save picture
# still working, have added  8956  random walkers.  Added to cluster:  350
# save picture
# still working, have added  8957  random walkers.  Added to cluster:  350
# save picture
# still working, have added  8958  random walkers.  Added to cluster:  350
# save picture
# still working, have added  8959  random walkers.  Added to cluster:  350
# save picture
# still working, have added  8960  random walkers.  Added to cluster:  350
# save picture
# still working, have added  9897  random walkers.  Added to cluster:  400
# save picture
# still working, have added  9898  random walkers.  Added to cluster:  400
# save picture
# still working, have added  9899  random walkers.  Added to cluster:  400
# save picture
# still working, have added  9900  random walkers.  Added to cluster:  400
# save picture
# still working, have added  9901  random walkers.  Added to cluster:  400
# save picture
# still working, have added  10559  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10560  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10561  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10562  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10563  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10564  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10565  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10566  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10567  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10568  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10569  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10570  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10571  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10572  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10573  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10574  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10575  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10576  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10577  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10578  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10579  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10580  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10581  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10582  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10583  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10584  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10585  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10586  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10587  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10588  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10589  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10590  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10591  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10592  random walkers.  Added to cluster:  450
# save picture
# still working, have added  10593  random walkers.  Added to cluster:  450
# save picture
# still working, have added  11485  random walkers.  Added to cluster:  500
# save picture
# still working, have added  11486  random walkers.  Added to cluster:  500
# save picture
# still working, have added  11487  random walkers.  Added to cluster:  500
# save picture
# still working, have added  11488  random walkers.  Added to cluster:  500
# save picture
# still working, have added  11489  random walkers.  Added to cluster:  500
# save picture
# still working, have added  11490  random walkers.  Added to cluster:  500
# save picture
# still working, have added  12292  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12293  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12294  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12295  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12296  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12297  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12298  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12299  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12300  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12301  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12302  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12303  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12304  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12305  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12306  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12307  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12308  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12309  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12310  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12311  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12312  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12313  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12314  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12315  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12316  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12317  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12318  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12319  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12320  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12321  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12322  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12323  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12324  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12325  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12326  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12327  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12328  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12329  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12330  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12331  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12332  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12333  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12334  random walkers.  Added to cluster:  550
# save picture
# still working, have added  12985  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12986  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12987  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12988  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12989  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12990  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12991  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12992  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12993  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12994  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12995  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12996  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12997  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12998  random walkers.  Added to cluster:  600
# save picture
# still working, have added  12999  random walkers.  Added to cluster:  600
# save picture
# still working, have added  13000  random walkers.  Added to cluster:  600
# save picture
# still working, have added  13851  random walkers.  Added to cluster:  650
# save picture
# still working, have added  13852  random walkers.  Added to cluster:  650
# save picture
# still working, have added  13853  random walkers.  Added to cluster:  650
# save picture
# still working, have added  13854  random walkers.  Added to cluster:  650
# save picture
# still working, have added  13855  random walkers.  Added to cluster:  650
# save picture
# still working, have added  14462  random walkers.  Added to cluster:  700
# save picture
# still working, have added  14463  random walkers.  Added to cluster:  700
# save picture
# still working, have added  14464  random walkers.  Added to cluster:  700
# save picture
# still working, have added  14465  random walkers.  Added to cluster:  700
# save picture
# still working, have added  14466  random walkers.  Added to cluster:  700
# save picture
# still working, have added  14467  random walkers.  Added to cluster:  700
# save picture
# still working, have added  15131  random walkers.  Added to cluster:  750
# save picture
# still working, have added  15132  random walkers.  Added to cluster:  750
# save picture
# still working, have added  15133  random walkers.  Added to cluster:  750
# save picture
# still working, have added  15134  random walkers.  Added to cluster:  750
# save picture
# still working, have added  15135  random walkers.  Added to cluster:  750
# save picture
# still working, have added  15902  random walkers.  Added to cluster:  800
# save picture
# still working, have added  15903  random walkers.  Added to cluster:  800
# save picture
# still working, have added  15904  random walkers.  Added to cluster:  800
# save picture
# still working, have added  15905  random walkers.  Added to cluster:  800
# save picture
# still working, have added  15906  random walkers.  Added to cluster:  800
# save picture
# still working, have added  15907  random walkers.  Added to cluster:  800
# save picture
# still working, have added  15908  random walkers.  Added to cluster:  800
# save picture
# still working, have added  15909  random walkers.  Added to cluster:  800
# save picture
# still working, have added  16312  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16313  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16314  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16315  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16316  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16317  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16318  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16319  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16320  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16321  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16322  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16323  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16324  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16325  random walkers.  Added to cluster:  850
# save picture
# still working, have added  16938  random walkers.  Added to cluster:  900
# save picture
# still working, have added  16939  random walkers.  Added to cluster:  900
# save picture
# still working, have added  16940  random walkers.  Added to cluster:  900
# save picture
# still working, have added  17557  random walkers.  Added to cluster:  950
# save picture
# still working, have added  17558  random walkers.  Added to cluster:  950
# save picture
# still working, have added  17559  random walkers.  Added to cluster:  950
# save picture
# still working, have added  18194  random walkers.  Added to cluster:  1000
# save picture
# still working, have added  18195  random walkers.  Added to cluster:  1000
# save picture
# still working, have added  18196  random walkers.  Added to cluster:  1000
# save picture
# still working, have added  18197  random walkers.  Added to cluster:  1000
# save picture
# still working, have added  18198  random walkers.  Added to cluster:  1000
# save picture
# still working, have added  18949  random walkers.  Added to cluster:  1050
# save picture
# still working, have added  18950  random walkers.  Added to cluster:  1050
# save picture
# still working, have added  19468  random walkers.  Added to cluster:  1100
# save picture
# still working, have added  19469  random walkers.  Added to cluster:  1100
# save picture
# still working, have added  19470  random walkers.  Added to cluster:  1100
# save picture
# still working, have added  19471  random walkers.  Added to cluster:  1100
# save picture
# still working, have added  19472  random walkers.  Added to cluster:  1100
# save picture
# still working, have added  19473  random walkers.  Added to cluster:  1100
# save picture
# still working, have added  19869  random walkers.  Added to cluster:  1150
# save picture
# still working, have added  19870  random walkers.  Added to cluster:  1150
# save picture
# still working, have added  19871  random walkers.  Added to cluster:  1150
# save picture
# still working, have added  19872  random walkers.  Added to cluster:  1150
# save picture
# still working, have added  20333  random walkers.  Added to cluster:  1200
# save picture
# still working, have added  20334  random walkers.  Added to cluster:  1200
# save picture
# still working, have added  20335  random walkers.  Added to cluster:  1200
# save picture
# still working, have added  20336  random walkers.  Added to cluster:  1200
# save picture
# still working, have added  20759  random walkers.  Added to cluster:  1250
# save picture
# still working, have added  20760  random walkers.  Added to cluster:  1250
# save picture
# still working, have added  21230  random walkers.  Added to cluster:  1300
# save picture
# still working, have added  21231  random walkers.  Added to cluster:  1300
# save picture
# still working, have added  21232  random walkers.  Added to cluster:  1300
# save picture
# still working, have added  21233  random walkers.  Added to cluster:  1300
# save picture
# still working, have added  21234  random walkers.  Added to cluster:  1300
# save picture
# still working, have added  21235  random walkers.  Added to cluster:  1300
# save picture
# still working, have added  21236  random walkers.  Added to cluster:  1300
# save picture
# still working, have added  21687  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21688  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21689  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21690  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21691  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21692  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21693  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21694  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21695  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21696  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21697  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21698  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21699  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21700  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21701  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21702  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21703  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21704  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21705  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21706  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21707  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21708  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21709  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21710  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21711  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21712  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21713  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21714  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21715  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21716  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21717  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21718  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21719  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21720  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21721  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21722  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21723  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21724  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21725  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21726  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21727  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21728  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21729  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21730  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21731  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21732  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21733  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21734  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21735  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21736  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21737  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21738  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21739  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21740  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  21741  random walkers.  Added to cluster:  1350
# save picture
# still working, have added  22073  random walkers.  Added to cluster:  1400
# save picture
# still working, have added  22074  random walkers.  Added to cluster:  1400
# save picture
# still working, have added  22533  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22534  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22535  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22536  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22537  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22538  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22539  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22540  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22541  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22542  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22543  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22544  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22545  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22546  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22547  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22548  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22549  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22550  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22551  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22552  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22553  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22554  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22555  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22556  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22557  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22558  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22559  random walkers.  Added to cluster:  1450
# save picture
# still working, have added  22905  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22906  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22907  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22908  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22909  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22910  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22911  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22912  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22913  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22914  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22915  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22916  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22917  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22918  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22919  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22920  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22921  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22922  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22923  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22924  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  22925  random walkers.  Added to cluster:  1500
# save picture
# still working, have added  23286  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23287  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23288  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23289  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23290  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23291  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23292  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23293  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23294  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23295  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23296  random walkers.  Added to cluster:  1550
# save picture
# still working, have added  23749  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23750  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23751  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23752  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23753  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23754  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23755  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23756  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23757  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23758  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23759  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23760  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23761  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23762  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  23763  random walkers.  Added to cluster:  1600
# save picture
# still working, have added  24097  random walkers.  Added to cluster:  1650
# save picture
# still working, have added  24098  random walkers.  Added to cluster:  1650
# save picture
# still working, have added  24099  random walkers.  Added to cluster:  1650
# save picture
# still working, have added  24100  random walkers.  Added to cluster:  1650
# save picture
# still working, have added  24101  random walkers.  Added to cluster:  1650
# save picture
# still working, have added  24102  random walkers.  Added to cluster:  1650
# save picture
# still working, have added  24411  random walkers.  Added to cluster:  1700
# save picture
# still working, have added  24412  random walkers.  Added to cluster:  1700
# save picture
# still working, have added  24413  random walkers.  Added to cluster:  1700
# save picture
# still working, have added  24414  random walkers.  Added to cluster:  1700
# save picture
# still working, have added  24415  random walkers.  Added to cluster:  1700
# save picture
# still working, have added  24722  random walkers.  Added to cluster:  1750
# save picture
# still working, have added  25125  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25126  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25127  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25128  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25129  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25130  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25131  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25132  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25133  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25134  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25135  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25136  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25137  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25138  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25139  random walkers.  Added to cluster:  1800
# save picture
# still working, have added  25541  random walkers.  Added to cluster:  1850
# save picture
# still working, have added  25542  random walkers.  Added to cluster:  1850
# save picture
# still working, have added  25543  random walkers.  Added to cluster:  1850
# save picture
# still working, have added  25544  random walkers.  Added to cluster:  1850
# save picture
# still working, have added  25545  random walkers.  Added to cluster:  1850
# save picture
# still working, have added  25546  random walkers.  Added to cluster:  1850
# save picture
# still working, have added  25850  random walkers.  Added to cluster:  1900
# save picture
# still working, have added  25851  random walkers.  Added to cluster:  1900
# save picture
# still working, have added  25852  random walkers.  Added to cluster:  1900
# save picture
# still working, have added  26166  random walkers.  Added to cluster:  1950
# save picture
# still working, have added  26167  random walkers.  Added to cluster:  1950
# save picture
# still working, have added  26535  random walkers.  Added to cluster:  2000
# save picture
# still working, have added  26536  random walkers.  Added to cluster:  2000
# save picture
# still working, have added  26537  random walkers.  Added to cluster:  2000
# save picture
# still working, have added  26876  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26877  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26878  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26879  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26880  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26881  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26882  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26883  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26884  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26885  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26886  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26887  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26888  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26889  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26890  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  26891  random walkers.  Added to cluster:  2050
# save picture
# still working, have added  27199  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27200  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27201  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27202  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27203  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27204  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27205  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27206  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27207  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27208  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27209  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27210  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27211  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27212  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27213  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27214  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27215  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27216  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27217  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27218  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27219  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27220  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27221  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27222  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27223  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27224  random walkers.  Added to cluster:  2100
# save picture
# still working, have added  27592  random walkers.  Added to cluster:  2150
# save picture
# still working, have added  27863  random walkers.  Added to cluster:  2200
# save picture
# still working, have added  27864  random walkers.  Added to cluster:  2200
# save picture
# still working, have added  27865  random walkers.  Added to cluster:  2200
# save picture
# still working, have added  27866  random walkers.  Added to cluster:  2200
# save picture
# still working, have added  27867  random walkers.  Added to cluster:  2200
# save picture
# still working, have added  28149  random walkers.  Added to cluster:  2250
# save picture
# still working, have added  28150  random walkers.  Added to cluster:  2250
# save picture
# still working, have added  28151  random walkers.  Added to cluster:  2250
# save picture
# still working, have added  28152  random walkers.  Added to cluster:  2250
# save picture
# still working, have added  28417  random walkers.  Added to cluster:  2300
# save picture
# still working, have added  28418  random walkers.  Added to cluster:  2300
# save picture
# still working, have added  28419  random walkers.  Added to cluster:  2300
# save picture
# still working, have added  28420  random walkers.  Added to cluster:  2300
# save picture
# still working, have added  28421  random walkers.  Added to cluster:  2300
# save picture
# Random walkers in the cluster:  2322
# CPU times: user 14min 31s, sys: 1min 50s, total: 16min 22s
# Wall time: 14min 43s
